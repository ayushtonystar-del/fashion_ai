# %%
# =====================================
# Fashion AI Internship
# Notebook 1 - Environment Setup
# =====================================

import os
import sys
import platform

print("=" * 50)
print("Fashion AI Environment Setup")
print("=" * 50)

print("Python Version :", sys.version)
print("Operating System :", platform.system())
print("Platform :", platform.platform())
# Out:
# ...
# Fashion AI Environment Setup
# ...
# Python Version : 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Operating System : Linux
# Platform : Linux-6.6.122+-x86_64-with-glibc2.35

# %%
# =====================================
# Check GPU
# =====================================

import torch

print("="*50)
print("GPU INFORMATION")
print("="*50)

print("CUDA Available :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU Name :", torch.cuda.get_device_name(0))
    print("GPU Count :", torch.cuda.device_count())
    print("CUDA Version :", torch.version.cuda)
else:
    print("No GPU detected.")
# Out:
# ...
# GPU INFORMATION
# ...
# CUDA Available : True
# GPU Name : Tesla T4
# GPU Count : 1
# CUDA Version : 12.8

# %%
# =====================================
# GPU Memory
# =====================================

# !nvidia-smi
# Out:
# Mon Jul 13 08:07:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# =====================================
# Clone Project
# =====================================

# !git clone https://github.com/ayushtonystar-del/fashion_ai.git
# Out:
# Cloning into 'fashion_ai'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 49 (delta 6), reused 36 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 42.95 KiB | 745.00 KiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd fashion_ai
# Out:
# /content/fashion_ai

# %%
# !pwd
# !ls -R
# Out:
# /content/fashion_ai
# .:
# backend   evaluation  LICENSE	outputs    requirement.txt  test_torch.py
# database  frontend    metadata	README.MD  scripts	    week2_report.md
#
# ./backend:
# api.py	image_service.py  prompt_builder.py
#
# ./database:
# chroma_db  chroma_setup.py  load_fashion_data.py  search.py  test_search.py
#
# ./database/chroma_db:
# chroma.sqlite3
#
# ./evaluation:
# clip_score.py  fid_score.py
#
# ./frontend:
# app.py
#
# ./metadata:
# fashion_knowledge.json	fashion_prompts.csv    prompt_library.json
# fashion_metadata.csv	fashion_taxonomy.json  prompt_templates.json
#
# ./outputs:
# prompts_experiment  reports
#
# ./outputs/prompts_experiment:
# exeperiment_1.json  exeperiment_2.json
#
# ./outputs/reports:
# category_distribution.png
#
# ./scripts:
# create_knowledge_base.py  extract_attributes.py
# dataset_analysis.py	  validate_dataset.py

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip install -q \
torch torchvision torchaudio \
diffusers \
transformers \
accelerate \
safetensors \
peft \
controlnet_aux \
opencv-python \
Pillow \
chromadb \
fastapi \
uvicorn \
gradio \
open_clip_torch \
datasets \
matplotlib \
pandas \
scikit-learn \
tqdm
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.3.0 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.43.0 which is incompatible.
# google-adk 2.3.0 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.43.0 which is incompatible.

# %%
import torch
import diffusers
import transformers
import chromadb
import cv2
import pandas as pd
import PIL

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import os

folders = [
    "datasets",
    "models",
    "logs",
    "generated_images",
    "evaluation_results"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Project directories created.")
# Out:
# Project directories created.

# %%
# =====================================
# Cell 11 : Create Dataset Directories
# =====================================

import os

directories = [
    "datasets",
    "datasets/images",
    "datasets/captions",
    "datasets/metadata",
    "models",
    "outputs",
    "logs",
    "evaluation_results"
]

for directory in directories:
    os.makedirs(directory, exist_ok=True)

print("="*60)
print("PROJECT DIRECTORIES CREATED SUCCESSFULLY")
print("="*60)

for directory in directories:
    print("✓", directory)
# Out:
# ...
# PROJECT DIRECTORIES CREATED SUCCESSFULLY
# ...
# ✓ datasets
# ✓ datasets/images
# ✓ datasets/captions
# ✓ datasets/metadata
# ✓ models
# ✓ outputs
# ✓ logs
# ✓ evaluation_results

# %%
# =====================================
# Cell 12 : Test ChromaDB
# =====================================

import chromadb

print("="*60)
print("INITIALIZING CHROMADB")
print("="*60)

client = chromadb.Client()

collection = client.create_collection("fashion_test")

collection.add(
    documents=[
        "Red cotton summer dress",
        "Blue denim jeans",
        "Black leather jacket"
    ],
    ids=["1","2","3"]
)

results = collection.query(
    query_texts=["summer dress"],
    n_results=2
)

print("Database Created Successfully")
print()
print("Search Results:")
print(results["documents"][0])
# Out:
# ...
# INITIALIZING CHROMADB
# ...
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:02<00:00, 35.9MiB/s]
# Database Created Successfully
#
# Search Results:
# ['Red cotton summer dress', 'Blue denim jeans']

# %%
# =====================================
# Cell 13 : Load OpenCLIP
# =====================================

import open_clip
import torch

print("="*60)
print("LOADING OPENCLIP MODEL")
print("="*60)

device = "cuda" if torch.cuda.is_available() else "cpu"

model, preprocess, tokenizer = open_clip.create_model_and_transforms(
    "ViT-B-32",
    pretrained="laion2b_s34b_b79k"
)

model.to(device)

print()
print("Device :", device)
print("Model Loaded Successfully")
# Out:
# ...
# LOADING OPENCLIP MODEL
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Device : cuda
# Model Loaded Successfully

# %%
# =====================================
# Cell 14 : Save Environment Report
# =====================================

import os
import platform
import torch
import transformers
import diffusers
import pandas as pd

report = {
    "Python": platform.python_version(),
    "OS": platform.system(),
    "CUDA Available": torch.cuda.is_available(),
    "GPU": torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU",
    "Torch": torch.__version__,
    "Transformers": transformers.__version__,
    "Diffusers": diffusers.__version__,
    "Pandas": pd.__version__
}

os.makedirs("logs", exist_ok=True)

with open("logs/environment_report.txt","w") as f:

    for key,value in report.items():
        f.write(f"{key}: {value}\n")

print("="*60)
print("ENVIRONMENT REPORT SAVED")
print("="*60)

print()

for key,value in report.items():
    print(f"{key}: {value}")
# Out:
# ...
# ENVIRONMENT REPORT SAVED
# ...
#
# Python: 3.12.13
# OS: Linux
# CUDA Available: True
# GPU: Tesla T4
# Torch: 2.11.0+cu128
# Transformers: 5.12.1
# Diffusers: 0.38.0
# Pandas: 2.2.2

# %%
# =====================================
# Cell 15 : Final Verification
# =====================================

print("="*60)
print("NOTEBOOK 1 COMPLETED SUCCESSFULLY")
print("="*60)

checklist = [
    "GPU Available",
    "GitHub Repository Cloned",
    "Dependencies Installed",
    "Directories Created",
    "ChromaDB Working",
    "OpenCLIP Loaded",
    "Environment Report Generated"
]

for item in checklist:
    print("✓", item)

print()

print("Next Notebook : 02_sdxl_generation.ipynb")
# Out:
# ...
# NOTEBOOK 1 COMPLETED SUCCESSFULLY
# ...
# ✓ GPU Available
# ✓ GitHub Repository Cloned
# ✓ Dependencies Installed
# ✓ Directories Created
# ✓ ChromaDB Working
# ✓ OpenCLIP Loaded
# ✓ Environment Report Generated
#
# Next Notebook : 02_sdxl_generation.ipynb
